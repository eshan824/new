# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd
import numpy as np
room22 = {"NAMES" : ["MAAZ","OSAID","SABOOR","ESHAN"],
         "DEPARTMENT" : ["ME", "EE","ME","EE"],
         "LAPTOPS" : ["LEVONO","HP","DELL","DELL"]}

df = pd.DataFrame(room22)
df
# Out:
#     NAMES DEPARTMENT LAPTOPS
# 0    MAAZ         ME  LEVONO
# 1   OSAID         EE      HP
# 2  SABOOR         ME    DELL
# 3   ESHAN         EE    DELL

# %%
df["GPA"] = ["3.2","4","3.5","1.9"]

# %%
df
# Out:
#     NAMES DEPARTMENT LAPTOPS  GPA
# 0    MAAZ         ME  LEVONO  3.2
# 1   OSAID         EE      HP    4
# 2  SABOOR         ME    DELL  3.5
# 3   ESHAN         EE    DELL  1.9

# %%
df.agg("GPA")
# Out:
# 0    3.2
# 1      4
# 2    3.5
# 3    1.9
# Name: GPA, dtype: object

# %%
df.GPA
# Out:
# 0    3.2
# 1      4
# 2    3.5
# 3    1.9
# Name: GPA, dtype: object

# %%
df
# Out:
#     NAMES DEPARTMENT LAPTOPS  GPA
# 0    MAAZ         ME  LEVONO  3.2
# 1   OSAID         EE      HP    4
# 2  SABOOR         ME    DELL  3.5
# 3   ESHAN         EE    DELL  1.9

# %%
room4 = {"NAMES" : ["SHIEKH","TAHIR","SAQLAIN","ABDULLAH"],
         "DEPARTMENT" : ["ME", "EE","EE","ME"],
         "LAPTOPS" : ["LEVONO","HP","DELL","DELL"]}

df1 = pd.DataFrame(room4)
df1
# Out:
#       NAMES DEPARTMENT LAPTOPS
# 0    SHIEKH         ME  LEVONO
# 1     TAHIR         EE      HP
# 2   SAQLAIN         EE    DELL
# 3  ABDULLAH         ME    DELL

# %%
df
# Out:
#     NAMES DEPARTMENT LAPTOPS  GPA
# 0    MAAZ         ME  LEVONO  3.2
# 1   OSAID         EE      HP    4
# 2  SABOOR         ME    DELL  3.5
# 3   ESHAN         EE    DELL  1.9

# %%
df1
# Out:
#       NAMES DEPARTMENT LAPTOPS
# 0    SHIEKH         ME  LEVONO
# 1     TAHIR         EE      HP
# 2   SAQLAIN         EE    DELL
# 3  ABDULLAH         ME    DELL

# %%
df.add(df1)
# Out:
#   DEPARTMENT  GPA       LAPTOPS          NAMES
# 0       MEME  NaN  LEVONOLEVONO     MAAZSHIEKH
# 1       EEEE  NaN          HPHP     OSAIDTAHIR
# 2       MEEE  NaN      DELLDELL  SABOORSAQLAIN
# 3       EEME  NaN      DELLDELL  ESHANABDULLAH

# %%
df1
# Out:
#       NAMES DEPARTMENT LAPTOPS
# 0    SHIEKH         ME  LEVONO
# 1     TAHIR         EE      HP
# 2   SAQLAIN         EE    DELL
# 3  ABDULLAH         ME    DELL

# %%
df1["GPA"] = ["3.1","3.3","3.5","3.1"]

# %%
df1
# Out:
#       NAMES DEPARTMENT LAPTOPS  GPA
# 0    SHIEKH         ME  LEVONO  3.1
# 1     TAHIR         EE      HP  3.3
# 2   SAQLAIN         EE    DELL  3.5
# 3  ABDULLAH         ME    DELL  3.1

# %%
df.add(df1)
# Out:
#            NAMES DEPARTMENT       LAPTOPS     GPA
# 0     MAAZSHIEKH       MEME  LEVONOLEVONO  3.23.1
# 1     OSAIDTAHIR       EEEE          HPHP    43.3
# 2  SABOORSAQLAIN       MEEE      DELLDELL  3.53.5
# 3  ESHANABDULLAH       EEME      DELLDELL  1.93.1

# %%
df
# Out:
#     NAMES DEPARTMENT LAPTOPS  GPA
# 0    MAAZ         ME  LEVONO  3.2
# 1   OSAID         EE      HP    4
# 2  SABOOR         ME    DELL  3.5
# 3   ESHAN         EE    DELL  1.9

# %%
df
# Out:
#     NAMES DEPARTMENT LAPTOPS  GPA
# 0    MAAZ         ME  LEVONO  3.2
# 1   OSAID         EE      HP    4
# 2  SABOOR         ME    DELL  3.5
# 3   ESHAN         EE    DELL  1.9

# %%
df.add(df1)
# Out:
#            NAMES DEPARTMENT       LAPTOPS     GPA
# 0     MAAZSHIEKH       MEME  LEVONOLEVONO  3.23.1
# 1     OSAIDTAHIR       EEEE          HPHP    43.3
# 2  SABOORSAQLAIN       MEEE      DELLDELL  3.53.5
# 3  ESHANABDULLAH       EEME      DELLDELL  1.93.1

# %%
df1
# Out:
#       NAMES DEPARTMENT LAPTOPS  GPA
# 0    SHIEKH         ME  LEVONO  3.1
# 1     TAHIR         EE      HP  3.3
# 2   SAQLAIN         EE    DELL  3.5
# 3  ABDULLAH         ME    DELL  3.1

# %%
df1.aggregate(["min", "mean"])
# Out:
#         NAMES DEPARTMENT LAPTOPS  GPA
# min  ABDULLAH         EE    DELL  3.1

# %%
df1.GPA.aggregate(["min","sum","max"])
# Out:
# min             3.1
# sum    3.13.33.53.1
# max             3.5
# Name: GPA, dtype: object

# %%
df.describe()
# Out:
#        NAMES DEPARTMENT LAPTOPS  GPA
# count      4          4       4    4
# unique     4          2       3    4
# top     MAAZ         ME    DELL  3.2
# freq       1          2       2    1

# %%
df
# Out:
#     NAMES DEPARTMENT LAPTOPS  GPA
# 0    MAAZ         ME  LEVONO  3.2
# 1   OSAID         EE      HP    4
# 2  SABOOR         ME    DELL  3.5
# 3   ESHAN         EE    DELL  1.9

# %%
df["TOWN"] = [np.nan,"GAOUN",np.nan,np.nan]

# %%
df
# Out:
#     NAMES DEPARTMENT LAPTOPS  GPA   TOWN
# 0    MAAZ         ME  LEVONO  3.2    NaN
# 1   OSAID         EE      HP    4  GAOUN
# 2  SABOOR         ME    DELL  3.5    NaN
# 3   ESHAN         EE    DELL  1.9    NaN

# %%
df.align( df["TOWN"] ,axis = 1)
# Out:
# (    0   1   2   3 DEPARTMENT  GPA LAPTOPS   NAMES   TOWN
#  0 NaN NaN NaN NaN         ME  3.2  LEVONO    MAAZ    NaN
#  1 NaN NaN NaN NaN         EE    4      HP   OSAID  GAOUN
#  2 NaN NaN NaN NaN         ME  3.5    DELL  SABOOR    NaN
#  3 NaN NaN NaN NaN         EE  1.9    DELL   ESHAN    NaN,
#  0               NaN
#  1             GAOUN
#  2               NaN
#  3               NaN
#  DEPARTMENT      NaN
#  GPA             NaN
#  LAPTOPS         NaN
#  NAMES           NaN
#  TOWN            NaN
#  Name: TOWN, dtype: object)

# %%
df
# Out:
#     NAMES DEPARTMENT LAPTOPS  GPA   TOWN
# 0    MAAZ         ME  LEVONO  3.2    NaN
# 1   OSAID         EE      HP    4  GAOUN
# 2  SABOOR         ME    DELL  3.5    NaN
# 3   ESHAN         EE    DELL  1.9    NaN

# %%
df.GPA
# Out:
# 0    3.2
# 1      4
# 2    3.5
# 3    1.9
# Name: GPA, dtype: object

# %%
df.TOWN
# Out:
# 0      NaN
# 1    GAOUN
# 2      NaN
# 3      NaN
# Name: TOWN, dtype: object

# %%
df.TOWN.isnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# Name: TOWN, dtype: bool

# %%
df.TOWN.notnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# Name: TOWN, dtype: bool

# %%
df
# Out:
#     NAMES DEPARTMENT LAPTOPS  GPA   TOWN
# 0    MAAZ         ME  LEVONO  3.2    NaN
# 1   OSAID         EE      HP    4  GAOUN
# 2  SABOOR         ME    DELL  3.5    NaN
# 3   ESHAN         EE    DELL  1.9    NaN

# %%
df.to_csv("E:/room22.csv", index = False)

# %%
df.append(df1)
# Out:
#       NAMES DEPARTMENT LAPTOPS  GPA   TOWN
# 0      MAAZ         ME  LEVONO  3.2    NaN
# 1     OSAID         EE      HP    4  GAOUN
# 2    SABOOR         ME    DELL  3.5    NaN
# 3     ESHAN         EE    DELL  1.9    NaN
# 0    SHIEKH         ME  LEVONO  3.1    NaN
# 1     TAHIR         EE      HP  3.3    NaN
# 2   SAQLAIN         EE    DELL  3.5    NaN
# 3  ABDULLAH         ME    DELL  3.1    NaN

# %%
df
# Out:
#     NAMES DEPARTMENT LAPTOPS  GPA   TOWN
# 0    MAAZ         ME  LEVONO  3.2    NaN
# 1   OSAID         EE      HP    4  GAOUN
# 2  SABOOR         ME    DELL  3.5    NaN
# 3   ESHAN         EE    DELL  1.9    NaN

# %%
df1
# Out:
#       NAMES DEPARTMENT LAPTOPS  GPA
# 0    SHIEKH         ME  LEVONO  3.1
# 1     TAHIR         EE      HP  3.3
# 2   SAQLAIN         EE    DELL  3.5
# 3  ABDULLAH         ME    DELL  3.1

# %%
df = df.append(df1)

# %%
df
# Out:
#       NAMES DEPARTMENT LAPTOPS  GPA   TOWN
# 0      MAAZ         ME  LEVONO  3.2    NaN
# 1     OSAID         EE      HP    4  GAOUN
# 2    SABOOR         ME    DELL  3.5    NaN
# 3     ESHAN         EE    DELL  1.9    NaN
# 0    SHIEKH         ME  LEVONO  3.1    NaN
# 1     TAHIR         EE      HP  3.3    NaN
# 2   SAQLAIN         EE    DELL  3.5    NaN
# 3  ABDULLAH         ME    DELL  3.1    NaN

# %%
df.to_csv("E:/room22.csv", index = False)

# %%
df
# Out:
#       NAMES DEPARTMENT LAPTOPS  GPA   TOWN
# 0      MAAZ         ME  LEVONO  3.2    NaN
# 1     OSAID         EE      HP    4  GAOUN
# 2    SABOOR         ME    DELL  3.5    NaN
# 3     ESHAN         EE    DELL  1.9    NaN
# 0    SHIEKH         ME  LEVONO  3.1    NaN
# 1     TAHIR         EE      HP  3.3    NaN
# 2   SAQLAIN         EE    DELL  3.5    NaN
# 3  ABDULLAH         ME    DELL  3.1    NaN

# %%
df = pd.read_csv("E:/room22.csv")

# %%
df
# Out:
#       NAMES DEPARTMENT LAPTOPS  GPA   TOWN
# 0      MAAZ         ME  LEVONO  3.2    NaN
# 1     OSAID         EE      HP  4.0  GAOUN
# 2    SABOOR         ME    DELL  3.5    NaN
# 3     ESHAN         EE    DELL  1.9    NaN
# 4    SHIEKH         ME  LEVONO  3.1    NaN
# 5     TAHIR         EE      HP  3.3    NaN
# 6   SAQLAIN         EE    DELL  3.5    NaN
# 7  ABDULLAH         ME    DELL  3.1    NaN

# %%
emails = []
for x in range(8):
    mail = f"{df.NAMES[x].title()}.{df.DEPARTMENT[0].lower()}@student.edu.pk"
    emails.append(mail)

df["EMAILS"] = emails

# %%
df
# Out:
#       NAMES DEPARTMENT LAPTOPS  GPA   TOWN                      EMAILS
# 0      MAAZ         ME  LEVONO  3.2    NaN      Maaz.me@student.edu.pk
# 1     OSAID         EE      HP  4.0  GAOUN     Osaid.me@student.edu.pk
# 2    SABOOR         ME    DELL  3.5    NaN    Saboor.me@student.edu.pk
# 3     ESHAN         EE    DELL  1.9    NaN     Eshan.me@student.edu.pk
# 4    SHIEKH         ME  LEVONO  3.1    NaN    Shiekh.me@student.edu.pk
# 5     TAHIR         EE      HP  3.3    NaN     Tahir.me@student.edu.pk
# 6   SAQLAIN         EE    DELL  3.5    NaN   Saqlain.me@student.edu.pk
# 7  ABDULLAH         ME    DELL  3.1    NaN  Abdullah.me@student.edu.pk

# %%
import string
import random
lower_case = string.ascii_lowercase
upper_case = string.ascii_uppercase
special_characters = ["!","@","#","$","%","^","&","*","<",">","-","~","`"]

pass_ = []
for x in range(8):
    password = f"{upper_case[random.choice(range(25))]}{lower_case[random.choice(range(25))]}{lower_case[random.choice(range(25))]}{lower_case[random.choice(range(25))]}{random.choice(range(9))}{special_characters[random.choice(range(12))]}{lower_case[random.choice(range(25))]}{special_characters[random.choice(range(12))]}"
    pass_.append(password)

#print(pass_)

df["PASSWORDS"] = pass_

#print(random.choice(range(25)))
#print(string.digits)

#Qpcz9@y^
df
# Out:
#       NAMES DEPARTMENT LAPTOPS  GPA   TOWN                      EMAILS  \
# 0      MAAZ         ME  LEVONO  3.2    NaN      Maaz.me@student.edu.pk
# 1     OSAID         EE      HP  4.0  GAOUN     Osaid.me@student.edu.pk
# 2    SABOOR         ME    DELL  3.5    NaN    Saboor.me@student.edu.pk
# 3     ESHAN         EE    DELL  1.9    NaN     Eshan.me@student.edu.pk
# 4    SHIEKH         ME  LEVONO  3.1    NaN    Shiekh.me@student.edu.pk
# 5     TAHIR         EE      HP  3.3    NaN     Tahir.me@student.edu.pk
# 6   SAQLAIN         EE    DELL  3.5    NaN   Saqlain.me@student.edu.pk
# 7  ABDULLAH         ME    DELL  3.1    NaN  Abdullah.me@student.edu.pk
#
#   PASSWORDS
# 0  Tkll1^b<
# 1  Qnwf6$q%
# 2  Ookb5&d<
# 3  Xcru0<q!
# 4  Gkni2!e#
# 5  Walj5%c@
# 6  Yhhc7&n$
# 7  Eabf5*h$

# %%
df
# Out:
#       NAMES DEPARTMENT LAPTOPS  GPA   TOWN                      EMAILS  \
# 0      MAAZ         ME  LEVONO  3.2    NaN      Maaz.me@student.edu.pk
# 1     OSAID         EE      HP  4.0  GAOUN     Osaid.me@student.edu.pk
# 2    SABOOR         ME    DELL  3.5    NaN    Saboor.me@student.edu.pk
# 3     ESHAN         EE    DELL  1.9    NaN     Eshan.me@student.edu.pk
# 4    SHIEKH         ME  LEVONO  3.1    NaN    Shiekh.me@student.edu.pk
# 5     TAHIR         EE      HP  3.3    NaN     Tahir.me@student.edu.pk
# 6   SAQLAIN         EE    DELL  3.5    NaN   Saqlain.me@student.edu.pk
# 7  ABDULLAH         ME    DELL  3.1    NaN  Abdullah.me@student.edu.pk
#
#   PASSWORDS
# 0  Tkll1^b<
# 1  Qnwf6$q%
# 2  Ookb5&d<
# 3  Xcru0<q!
# 4  Gkni2!e#
# 5  Walj5%c@
# 6  Yhhc7&n$
# 7  Eabf5*h$

# %%
df.to_csv("E:/room22.csv", index = False)

# %%
#df.iloc[0][2]
i = 0
j = 0
inner_list = []
outer_list = []
for x in range(8):
    for y in range(7):
        #dict = { }
        
        values = f"{df.columns[j]} : {df.iloc[i][j]}"
        inner_list.append(values)
        j += 1
    
    #outer_list.append(inner_list)
    i += 1
    j = 0

print(inner_list)
# Out:
# ['NAMES : MAAZ', 'DEPARTMENT : ME', 'LAPTOPS : LEVONO', 'GPA : 3.2', 'TOWN : nan', 'EMAILS : Maaz.me@student.edu.pk', 'PASSWORDS : Tkll1^b<', 'NAMES : OSAID', 'DEPARTMENT : EE', 'LAPTOPS : HP', 'GPA : 4.0', 'TOWN : GAOUN', 'EMAILS : Osaid.me@student.edu.pk', 'PASSWORDS : Qnwf6$q%', 'NAMES : SABOOR', 'DEPARTMENT : ME', 'LAPTOPS : DELL', 'GPA : 3.5', 'TOWN : nan', 'EMAILS : Saboor.me@student.edu.pk', 'PASSWORDS : Ookb5&d<', 'NAMES : ESHAN', 'DEPARTMENT : EE', 'LAPTOPS : DELL', 'GPA : 1.9', 'TOWN : nan', 'EMAILS : Eshan.me@student.edu.pk', 'PASSWORDS : Xcru0<q!', 'NAMES : SHIEKH', 'DEPARTMENT : ME', 'LAPTOPS : LEVONO', 'GPA : 3.1', 'TOWN : nan', 'EMAILS : Shiekh.me@student.edu.pk', 'PASSWORDS : Gkni2!e#', 'NAMES : TAHIR', 'DEPARTMENT : EE', 'LAPTOPS : HP', 'GPA : 3.3', 'TOWN : nan', 'EMAILS : Tahir.me@student.edu.pk', 'PASSWORDS : Walj5%c@', 'NAMES : SAQLAIN', 'DEPARTMENT : EE', 'LAPTOPS : DELL', 'GPA : 3.5', 'TOWN : nan', 'EMAILS : Saqlain.me@student.edu.pk', 'PASSWORDS : Yhhc7&n$', 'N
# ...

# %%
df
# Out:
#       NAMES DEPARTMENT LAPTOPS  GPA   TOWN                      EMAILS  \
# 0      MAAZ         ME  LEVONO  3.2    NaN      Maaz.me@student.edu.pk
# 1     OSAID         EE      HP  4.0  GAOUN     Osaid.me@student.edu.pk
# 2    SABOOR         ME    DELL  3.5    NaN    Saboor.me@student.edu.pk
# 3     ESHAN         EE    DELL  1.9    NaN     Eshan.me@student.edu.pk
# 4    SHIEKH         ME  LEVONO  3.1    NaN    Shiekh.me@student.edu.pk
# 5     TAHIR         EE      HP  3.3    NaN     Tahir.me@student.edu.pk
# 6   SAQLAIN         EE    DELL  3.5    NaN   Saqlain.me@student.edu.pk
# 7  ABDULLAH         ME    DELL  3.1    NaN  Abdullah.me@student.edu.pk
#
#   PASSWORDS
# 0  Tkll1^b<
# 1  Qnwf6$q%
# 2  Ookb5&d<
# 3  Xcru0<q!
# 4  Gkni2!e#
# 5  Walj5%c@
# 6  Yhhc7&n$
# 7  Eabf5*h$

# %%
df.count(axis = 1)
# Out:
# 0    6
# 1    7
# 2    6
# 3    6
# 4    6
# 5    6
# 6    6
# 7    6
# dtype: int64
